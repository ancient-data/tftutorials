# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/ninologo.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# previous: [start](start.ipynb)
#
# ---
#
# # Search

# %%
from tf.app import use

# %%
A = use('oldbabylonian', hoist=globals(), silent='deep')
silentOff()
# Out:
# <style>
# @font-face {
#   font-family: "Santakku";
#   src:
#     local("Santakku.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtr,.txtr a:visited,.txtr a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Santakku;
#     font-size: x-large;
#     text-decoration: none;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.document {
#     flex-flow: column nowrap;
# }
# .children.face {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.word {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.document,.contnr.face,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.document,.contnr.face {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.document,.lbl.face,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.document,.lbl.face {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srclnnum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .comment {
#     color: #7777dd;
#     font-family: monospace;
#     font-size: small;
# }
# .operator {
#     color: #ff77ff;
#     font-size: large;
# }
# /* LANGUAGE: superscript and subscript */
#
# /* cluster */
# .det {
#     vertical-align: super;
# }
# /* cluster */
# .langalt {
#     vertical-align: sub;
# }
# /* REDACTIONAL: line over or under  */
#
# /* flag */
# .collated {
#     font-weight: bold;
#     text-decoration: underline;
# }
# /* cluster */
# .excised {
#     color: #dd0000;
#     text-decoration: line-through;
# }
# /* cluster */
# .supplied {
#     color: #0000ff;
#     text-decoration: overline;
# }
# /* flag */
# .remarkable {
#     font-weight: bold;
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# /* cluster */
# .uncertain {
#     font-style: italic
# }
# /* flag */
# .question {
#     font-weight: bold;
#     font-style: italic
# }
#
# /* BROKEN: text-shadow */
#
# /* cluster */
# .missing {
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# /* flag */
# .damage {
#     font-weight: bold;
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# .empty {
#   color: #ff0000;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>

# %% [markdown]
# # Numerals at least 3 times

# %%
query = '''
word
  sign type=numeral repeat>3
'''
results = A.search(query)
A.table(results, end=10, fmt='layout-orig-rich')
# Out:
#   0.18s 546 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">word</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:11">P509373 obverse:11</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">7</span>⌈<span class="r">diš</span>⌉</span> </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">7</span>⌈<span class="r">diš</span>⌉</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="show this document on CDLI" sec="P509376 obverse:4">P509376 obverse:4</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="P509376 obverse:4" sec="P509376 obverse:4"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">4</span>⌈<span class="r">diš</span>⌉</span>-</span><span  class="hlup" ><span class="langalt"><span class="r">kam</span></span> </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">4</span>⌈<span class="r">diš</span>⌉</span>-</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="show this document on CDLI" sec="P509377 reverse:10">P509377 reverse:10</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="P509377 reverse:10" sec="P509377 reverse:10"><span class="txtr"><span  class="hl hlup" ><span class="quantity">6</span>⌈<span class="r">diš</span>⌉ </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="quantity">6</span>⌈<span class="r">diš</span>⌉ </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="show this document on CDLI" sec="P389958 obverse:7'">P389958 obverse:7'</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="P389958 obverse:7'" sec="P389958 obverse:7'"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">5</span>⌈<span class="r">diš</span>⌉</span> </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">5</span>⌈<span class="r">diš</span>⌉</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="show this document on CDLI" sec="P510527 reverse:11">P510527 reverse:11</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="P510527 reverse:11" sec="P510527 reverse:11"><span class="txtr"><span  class="hlup" ><span class="langalt"><span class="r">igi</span></span>-</span><span  class="hl hlup" ><span class="langalt"><span class="quantity">6</span>⌈<span class="r">diš</span>⌉</span>-</span><span  class="hlup" ><span class="langalt"><span class="r">gal₂</span></span> </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">6</span>⌈<span class="r">diš</span>⌉</span>-</span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:17">P510530 reverse:17</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:17" sec="P510530 reverse:17"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">4</span>⌈<span class="r">diš</span>⌉</span>-</span><span  class="hlup" ><span class="langalt"><span class="r">kam</span></span></span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">4</span>⌈<span class="r">diš</span>⌉</span>-</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:5'">P510534 reverse:5'</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:5'" sec="P510534 reverse:5'"><span class="txtr"><span  class="hl hlup" ><span class="quantity">4</span>⌈<span class="r">diš</span>⌉ </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="quantity">4</span>⌈<span class="r">diš</span>⌉ </span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:10'">P510534 reverse:10'</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:10'" sec="P510534 reverse:10'"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">5</span>⌈<span class="r">diš</span>⌉</span>-</span><span  class="hlup" ><span class="langalt"><span class="r">ta</span></span>-</span><span  class="hlup" ><span class="langalt"><span class="r">am₃</span></span> </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="langalt"><span class="quantity">5</span>⌈<span class="r">diš</span>⌉</span>-</span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="show this document on CDLI" sec="P510536 obverse:5">P510536 obverse:5</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="P510536 obverse:5" sec="P510536 obverse:5"><span class="txtr"><span  class="hl hlup" ><span class="quantity">6</span>⌈<span class="r">diš</span>⌉ </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="quantity">6</span>⌈<span class="r">diš</span>⌉ </span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="show this document on CDLI" sec="P510539 obverse:7">P510539 obverse:7</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="P510539 obverse:7" sec="P510539 obverse:7"><span class="txtr"><span  class="hl hlup" ><span class="quantity">4</span>⌈<span class="r">diš</span>⌉ </span></span></a></td><td class="tf"><span class="txtr"><span  class="hl hlup" ><span class="quantity">4</span>⌈<span class="r">diš</span>⌉ </span></span></td></tr></table>

# %%
A.table(results, end=10, fmt='layout-orig-unicode')
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">word</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:11">P509373 obverse:11</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐌</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐌</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="show this document on CDLI" sec="P509376 obverse:4">P509376 obverse:4</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="P509376 obverse:4" sec="P509376 obverse:4"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐉</span></span><span  class="hlup" ><span class="langalt"><span class="r">𒄭𒁁</span></span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐉</span></span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="show this document on CDLI" sec="P509377 reverse:10">P509377 reverse:10</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="P509377 reverse:10" sec="P509377 reverse:10"><span class="txtu"><span  class="hl hlup" >𒐋 </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >𒐋 </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="show this document on CDLI" sec="P389958 obverse:7'">P389958 obverse:7'</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="P389958 obverse:7'" sec="P389958 obverse:7'"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐊</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐊</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="show this document on CDLI" sec="P510527 reverse:11">P510527 reverse:11</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="P510527 reverse:11" sec="P510527 reverse:11"><span class="txtu"><span  class="hlup" ><span class="langalt"><span class="r">𒅆</span></span></span><span  class="hl hlup" ><span class="langalt">𒐋</span></span><span  class="hlup" ><span class="langalt"><span class="r">𒅅</span></span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐋</span></span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:17">P510530 reverse:17</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:17" sec="P510530 reverse:17"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐉</span></span><span  class="hlup" ><span class="langalt"><span class="r">𒄭𒁁</span></span></span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐉</span></span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:5'">P510534 reverse:5'</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:5'" sec="P510534 reverse:5'"><span class="txtu"><span  class="hl hlup" >𒐉 </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >𒐉 </span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:10'">P510534 reverse:10'</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:10'" sec="P510534 reverse:10'"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐊</span></span><span  class="hlup" ><span class="langalt"><span class="r">𒋫</span></span></span><span  class="hlup" ><span class="langalt"><span class="r">𒀀𒀭</span></span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" ><span class="langalt">𒐊</span></span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="show this document on CDLI" sec="P510536 obverse:5">P510536 obverse:5</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="P510536 obverse:5" sec="P510536 obverse:5"><span class="txtu"><span  class="hl hlup" >𒐋 </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >𒐋 </span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="show this document on CDLI" sec="P510539 obverse:7">P510539 obverse:7</a></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="P510539 obverse:7" sec="P510539 obverse:7"><span class="txtu"><span  class="hl hlup" >𒐉 </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >𒐉 </span></span></td></tr></table>

# %%
A.show(results, start=1, end=3)
# A.show(results, start=1, end=3, fmt='layout-orig-unicode')
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_{d}utu_-ha-zi-[ir] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">utu_-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ha-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">zi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[ir] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">isz-tu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">isz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_mu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_mu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtp">7(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">7(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>7</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">id-di-nu-szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">id-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="P509376 obverse:4" sec="P509376 obverse:4">line <span class="txtn">4</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtp">4(disz)-kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">4(disz)-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>4</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na-an-na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">an-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="P509377 reverse:10" sec="P509377 reverse:10">line <span class="txtn">10</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szum-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtp">6(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">6(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="repeat"><span class="f">repeat=</span>6</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_gin2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_gin2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ku3-babbar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ku3-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">babbar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-di-in-szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Custom highlighting

# %%
query = '''
line
  sign missing=1
  sign question=1
  sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})

# %%
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})

# %% [markdown]
# ---
#
# next: [posTag](posTag.ipynb)
#
# ---
#
# full posTag and pos notebooks on
# [annotation/tutorials/oldbabylonian/cookbook](https://nbviewer.jupyter.org/github/annotation/tutorials/blob/master/oldbabylonian/cookbook)
#
# full tutorial on
# [annotation/tutorials/oldbabylonian](https://nbviewer.jupyter.org/github/annotation/tutorials/blob/master/oldbabylonian)
